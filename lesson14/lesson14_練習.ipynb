# %%
'''
請幫我畫以下的圖

pie文件說明 = https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.pie.html

labels = ['Nokia', 'Samsung', 'Apple', 'Lumia']
values = [20, 30, 45, 10]
colors = ['yellow', 'green', 'red', 'blue']

'''

# %%
import matplotlib.pyplot as plt

def main(): 
    labels = ['Nokia', 'Samsung', 'Apple', 'Lumia']
    values = [20, 30, 45, 10]
    colors = ['yellow', 'green', 'red', 'blue']

    figure = plt.figure(figsize=(5.0,5.0))
    axes = figure.add_subplot()
    axes.pie(values,explode=[0.3,0,0,0], labels=labels, colors=colors, autopct='%1.1f%%', shadow=1, startangle=180)
    plt.show()

if __name__ == '__main__':
    main()
